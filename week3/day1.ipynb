# %% [markdown]
# Here is the link to the code for google colab: for day 1 (week 3)
#
# - Huggingface and Google colab introduction
#
# [week 3 - day 1](https://colab.research.google.com/drive/1pkid69zBDchBSCZjq1NiKc4mw8tUorpK#scrollTo=yQJbZbtcbPmy)
