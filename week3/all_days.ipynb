# %% [markdown]
# ### Here is the link to the code for google colab: for week 3
#
# - Day 1: Huggingface and Google colab introduction
#
# [week 3 - day 1](https://colab.research.google.com/drive/1pkid69zBDchBSCZjq1NiKc4mw8tUorpK#scrollTo=yQJbZbtcbPmy)
#
# - Day 2: Introduction to pipelines in huggingface
#
# [week 3 - day 2](https://colab.research.google.com/drive/1wXlMaOQUGLVNeOubGeGFpWW6dy2mf8zw#scrollTo=B-iTDBmhhDQq)
